# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
pil = Image.open("Batman.jpg")

# %%
arr = np.array(pil)

# %%
cut = arr[0:100, :200]
plt.imshow(pil)

# %%
red= arr.copy();
red[:,:,[1,2]]=0;
plt.imshow(red)

# %%
gray = arr.mean(axis=2)
plt.imshow(gray)

# %%
img = cv2.imread('Batman.jpg')
plt.imshow(img)

# %%
# Out:
# 'C:\\Users\\91771\\anaconda3\\lib\\site-packages\\cv2\\data\\'
