# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.imread('building.jpg',cv2.IMREAD_GRAYSCALE)
img
# Out:
# array([[217, 217, 218, ..., 219, 219, 219],
#        [217, 217, 218, ..., 219, 219, 219],
#        [217, 217, 218, ..., 219, 219, 219],
#        ...,
#        [ 32,  12,  28, ...,  59,  58,  63],
#        [ 22,   8,  23, ...,  63,  57,  71],
#        [ 16,   7,  20, ...,  44,  42,  53]], dtype=uint8)

# %%
plt.imshow(img,cmap='gray')
print("Original Image")
# Out:
# Original Image

# %%
from scipy.signal import convolve2d
filterarr = np.array([[-1,-1,-1],[0,0,0],[1,1,1]])
convolved_image = convolve2d(img, filterarr, mode='same', boundary='wrap')
convolved_image[convolved_image<0]=0

# %%
plt.imshow(convolved_image,cmap='gray')
print("Horizontal Edges")
# Out:
# Horizontal Edges

# %%
filterarr = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
convolved_image = convolve2d(img, filterarr, mode='same', boundary='wrap')
convolved_image[convolved_image<0]=0
plt.imshow(convolved_image,cmap='gray')
print("Vertical Edges")
# Out:
# Vertical Edges
