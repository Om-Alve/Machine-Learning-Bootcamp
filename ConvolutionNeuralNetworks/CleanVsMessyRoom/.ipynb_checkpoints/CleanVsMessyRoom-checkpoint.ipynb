# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPool2D,Flatten,BatchNormalization,Dropout
from keras.optimizers import Adam,SGD

# %%
train_data = keras.utils.image_dataset_from_directory(
    directory='images/train',
    labels='inferred',
    label_mode='int',
    batch_size = 10,
    image_size=(256,256)
)
test_data = keras.utils.image_dataset_from_directory(
    directory='images/val',
    labels='inferred',
    label_mode='int',
    batch_size = 10,
    image_size=(256,256)
)
# Out:
# Found 192 files belonging to 2 classes.
# Found 30 files belonging to 2 classes.

# %%
def normalize(image,label):
    image = tf.cast(image/255,tf.float32)
    return image,label
train_data = train_data.map(normalize)
test_data = test_data.map(normalize)

# %%
model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3),padding='same',activation='relu',input_shape=(256,256,3)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(filters=128,kernel_size=(3,3),padding='same',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 256, 256, 32)      896
#
#  batch_normalization_3 (Bat  (None, 256, 256, 32)      128
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 128, 128, 32)      0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 126, 126, 64)      18496
#
#  batch_normalization_4 (Bat  (None, 126, 126, 64)      256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 63, 63, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 63, 63, 128)       73856
#
#  batch_normalization_5 (Bat  (None, 63, 63, 128)       512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 31, 31, 128)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 123008)            0
#
#  dense_3 (Dense)             (None, 128)               15745152
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 15847617 (60.45 MB)
# Trainable params: 15847169 (60.45 MB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
opt = SGD(learning_rate=0.001,momentum=0.9)
model.compile(optimizer=opt,loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(train_data,epochs=20,validation_data=test_data)
# Out:
# Epoch 1/20
# 20/20 [==============================] - 25s 1s/step - loss: 0.5993 - accuracy: 0.9531 - val_loss: 314.1475 - val_accuracy: 0.3333
# Epoch 2/20
# 20/20 [==============================] - 22s 1s/step - loss: 7.6952 - accuracy: 0.8542 - val_loss: 1491.8621 - val_accuracy: 0.3333
# Epoch 3/20
# 20/20 [==============================] - 23s 1s/step - loss: 8.0697 - accuracy: 0.8385 - val_loss: 383.7203 - val_accuracy: 0.3333
# Epoch 4/20
# 20/20 [==============================] - 23s 1s/step - loss: 4.4053 - accuracy: 0.9323 - val_loss: 692.5674 - val_accuracy: 0.3333
# Epoch 5/20
# 20/20 [==============================] - 22s 1s/step - loss: 4.0981 - accuracy: 0.9010 - val_loss: 102.4983 - val_accuracy: 0.3333
# Epoch 6/20
# 20/20 [==============================] - 21s 1s/step - loss: 1.2960 - accuracy: 0.9375 - val_loss: 83.4937 - val_accuracy: 0.3333
# Epoch 7/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.7533 - accuracy: 0.9323 - val_loss: 59.7857 - val_accuracy: 0.3333
# Epoch 8/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.6123 - accuracy: 0.9375 - val_loss: 37.1642 - val_accuracy: 0.3333
# Epoch 9/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.2524 - accuracy: 0.9479 - val_loss: 53.8827 - val_accuracy: 0.3333
# Epoch 10/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.0857 - accuracy: 0.9896 - val_loss: 39.3020 - val_accuracy: 0.3333
# Epoch 11/20
# 20/20 [==============================] - 25s 1s/step - loss: 0.1241 - accuracy: 0.9948 - val_loss: 6.2277 - val_accuracy: 0.7000
# Epoch 12/20
# 20/20 [==============================] - 25s 1s/step - loss: 0.0808 - accuracy: 0.9792 - val_loss: 3.9702 - val_accuracy: 0.6333
# Epoch 13/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.3897 - accuracy: 0.9635 - val_loss: 3.9917 - val_accuracy: 0.6000
# Epoch 14/20
# 20/20 [==============================] - 21s 1s/step - loss: 0.1330 - accuracy: 0.9740 - val_loss: 2.5695 - val_accuracy: 0.7667
# Epoch 15/20
# 20/20 [==============================] - 21s 1s/step - loss: 0.1130 - accuracy: 0.9740 - val_loss: 3.2344 - val_accuracy: 0.6667
# Epoch 16/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.0678 - accuracy: 0.9896 - val_loss: 4.6676 - val_accuracy: 0.6333
# Epoch 17/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.0973 - accuracy: 0.9792 - val_loss: 1.9787 - val_accuracy: 0.6667
# Epoch 18/20
# 20/20 [==============================] - 23s 1s/step - loss: 0.2610 - accuracy: 0.9740 - val_loss: 4.8176 - val_accuracy: 0.6333
# Epoch 19/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.0874 - accuracy: 0.9896 - val_loss: 5.0405 - val_accuracy: 0.6333
# Epoch 20/20
# 20/20 [==============================] - 22s 1s/step - loss: 0.0778 - accuracy: 0.9896 - val_loss: 3.9415 - val_accuracy: 0.6333

# %%
import cv2
import matplotlib.pyplot as plt

# %%
path = 'images/test/room.jpg'
img = cv2.imread(path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img = cv2.resize(img,(256,256))
plt.imshow(img)
plt.axis('off')
img = img.reshape((1,256,256,3))
pred = "Clean" if model.predict(img)[0] == 0 else "Messy"
plt.title(pred)
plt.show()
# Out:
# 1/1 [==============================] - 0s 434ms/step

# %%
fig,axes = plt.subplots(2,5,figsize=(16,8))
k=0

for i in range(2):
    for j in range(5):
        path = f'images/test/{k}.png'
        k+=1
        img = cv2.imread(path)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img,(256,256))
        img=img / 255
        axes[i][j].imshow(img)
        axes[i][j].axis('off')
        img = img.reshape((1,256,256,3))
        pred = "Clean" if model.predict(img)[0] == 0 else "Messy"
        axes[i][j].set_title(pred)
# Out:
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 76ms/step

# %% [markdown]
# # Using Data Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
# create data generators
train_datagen = ImageDataGenerator(rescale=1.0/255.0,
 width_shift_range=0.2, height_shift_range=0.2,rotation_range=10,zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1.0/255.0)

# %%
train = train_datagen.flow_from_directory('images/train/',
    class_mode='binary', batch_size=10, target_size=(256, 256))
test = test_datagen.flow_from_directory('images/val/',
    class_mode='binary', batch_size=10, target_size=(256, 256))

# %%
model = Sequential()
model.add(Conv2D(16,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3)))
model.add(BatchNormalization())
model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))
model.add(Conv2D(filters=128,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.summary()

# %%
model.fit(train,validation_data=test,epochs=25)

# %%
fig,axes = plt.subplots(2,5,figsize=(16,8))
k=0

for i in range(2):
    for j in range(5):
        path = f'images/train/clean/{k}.png'
        k+=1
        img = cv2.imread(path)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
        img = cv2.resize(img,(256,256))
        axes[i][j].imshow(img)
        axes[i][j].axis('off')
        img = img.reshape((1,256,256,3))
        img = img/255
        # img = test_datagen.flow(img)
        pred = "Clean" if model.predict(img)[0] == 0 else "Messy"
        axes[i][j].set_title(pred)
