# %%
import pandas as pd

# %%
df = pd.read_csv('Advertising.csv',index_col=0)
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
import seaborn as sns

# %%
sns.pairplot(df,x_vars=["TV","Radio","Newspaper"],y_vars=["Sales"],height=7,aspect=0.7,kind="reg")

# %%
from sklearn.model_selection import train_test_split
X = df[["TV","Radio","Newspaper"]]
y = df['Sales']
X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
feature_cols = ["TV","Radio","Newspaper"]
zip(feature_cols,lr.coef_)

# %%
pred = lr.predict(X_test)
pred
# Out:
# array([15.45380022, 12.08792121, 12.14166   , 10.85737286, 12.2328868 ,
#        20.46725741, 15.27514083,  5.77736048, 10.72808832, 21.82910003,
#         7.78927527, 11.43963988,  8.91676693,  7.05411112, 13.91326955,
#        14.22391257, 17.47108472, 16.59693476, 19.79077048, 19.08443953,
#        17.04208149, 13.73860908, 11.47480693, 11.29298872, 21.13529123,
#        18.14139449, 15.5312531 ,  6.54019945, 16.85285337, 17.17916163,
#        14.26417179,  8.7330657 , 18.36100202, 20.78755799, 20.48692609,
#        11.60360155,  9.14506337, 19.20301788, 10.61491887, 21.00429942,
#        24.03587896, 17.73572983,  6.06826921, 15.25944381, 17.74939399,
#         9.87035678, 22.85401337, 14.12440984, 21.15674078, 15.27019922])
